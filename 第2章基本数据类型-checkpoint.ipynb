# %% [markdown]
#  # 第2章基本数据类型

# %% [markdown]
# ## 2.1　导学

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 学习目标：
# 1.	编写程序完成简单的计算。
# 2.	使用input函数接受用户输入
# 3.	掌握标识符命名规范
# 4.	熟悉各种运算符的使用
# 5.	熟悉使用运算符构造表达式
# 6.	了解常见的数学、时间函数

# %% [markdown]
# ## 2.2　变量

# %% [markdown]
# ### 2.2.1　变量的定义

# %% [markdown]
# 为什么在编程中需要引入变量呢？ 首先，数据经常发生变化，比如年龄。变量的值就可以根据年龄随时改变。比如：

# %%
age = 13
age = 14

# %% [markdown]
#    其次，通过变量的规范命名，在阅读代码时更容易让人记住并理解变量值的意义。比较下例中两次输出代码：

# %%
print(25000 - 4000 - 1000 - 800)

income = 55000       # 工资收入
rent_cost = 4000     # 房租
meals_cost = 1000    # 伙食费
other_cost = 800     # 其他费用

print(income - rent_cost - meals_cost - other_cost)

# %% [markdown]
#    最后，如果程序中会多次用到某个变量值，修改的时候所以使用到该变量的地方都会修改，大大方便了编程。
#    变量相当于一个贴着标签的盒子，里面放着一个可以使用任意类型的值。标签名称不变，但盒子里面的值会发生变化。
#    变量就是存储在内存中的值。这就意味着在创建变量时会在内存中开辟一个空间。基于变量的数据类型，解释器会分配指定内存，并决定什么数据可以被存储在内存中。因此，变量可以指定不同的数据类型，这些变量可以存储整数，小数或字符。

# %%
message = "Hello Python world!"
print(message)

# %% [markdown]
#   进一步扩展这个程序：修改 hello_world.py，使其再打印一条消息。为此，在hello_world.py中添加一个空行，再添加下面两行代码：

# %%
message = "Hello Python world!"
print(message)
message = "Hello Python Crash Course world!"
print(message)

# %% [markdown]
# 在程序中可随时修改变量的值，而Python将始终记录变量的最新值。

# %% [markdown]
# ### 常量

# %% [markdown]
# 常量指在程序的执行过程中不变的量
# 1,2,3,4；   1.1， 1.2，  1.0
# 'abc', "Python"
# True , False

# %% [markdown]
# * 符号常量

# %%
from math import *
pi

# %%
e

# %% [markdown]
# ### 2.2.2　变量命名规则

# %% [markdown]
# 有关变量的规则：
#
# ①	变量名只能包含字母、数字和下划线。变量名可以字母或下划线打头，但不能以数字打头，例如，可将变量命名为message_1，但不能将其命名为1_message。
# ②	变量名不能包含空格，但可使用下划线来分隔其中的单词。例如，变量名 greeting _message可行，但变量名 greeting message会引发错误。
# ③	不要将Python关键字和函数名用作变量名，即不要使用Python保留用于特殊用途的单词。
# ④	变量名应既简短又具有描述性。例如，name比n好，student_name比s_n好， name_length比length_of_persons_name好。
# ⑤	慎用小写字母l和大写字母O，因为它们可能被人错看成数字1和0。
# 就目前而言，应使用小写的Python变量名。在变量名中使用大写字母虽然不会导致错误，避免使用大写字母。
# 要创建良好的变量名，需要经过一定的实践，在程序复杂而有趣时尤其如此。随着各位编写的程序越来越多，并开始阅读他人编写的代码，将越来越善于创建有意义的变量名。
#
# 下面的代码中，输出了变量 message的值，但不小心输错了变量的名称。

# %%
message = "Hello Python Crash Course reader!"
print(mesage)

# %% [markdown]
# 程序无法成功运行时，解释器会提供一个traceback。traceback是一条记录，指出了解释器尝试运行代码时，在什么地方陷入了困境。

# %% [markdown]
# ### 2.2.3　关键字

# %% [markdown]
# 关键字，又称保留字，编程者不能把它们用作任何标识符名称。Python的标准库提供了一个keyword模块，可以输出当前版本的所有关键字：

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# ### 2.2.4　变量赋值

# %% [markdown]
# Python中的变量赋值不需要类型声明。每个变量在内存中创建，都包括变量的标识，名称和数据这些信息。每个变量在使用前都必须赋值，语法如下：
# （无需声明变量类型）

# %%
var = value

# %% [markdown]
# 变量赋值以后该变量才会被创建。比如下面的counter没有赋值就使用：

# %%
print(counter)

# %% [markdown]
# 等号（=）用来给变量赋值。等号（=）运算符左边是一个变量名,等号（=）运算符右边是存储在变量中的值。例如：

# %%
counter = 100 # 赋值整型变量
miles = 1000.0 # 浮点型
name = "John" # 字符串
 
print(counter)
print(miles)
print(name)

# %% [markdown]
# Python允许一条语句同时为多个变量赋值。例如：

# %%
a = b = c = 1

# %% [markdown]
# 以上实例，创建一个整型对象，值为1，三个变量被分配到相同的内存空间上。各位也可以为多个对象指定多个变量。例如：

# %%
a, b, c = 1, 2, "john"

# %% [markdown]
# 可以使用del语句删除一些对象引用。del语句的语法是：

# %%
del var1[,var2[,var3[....,varN]]]

# %% [markdown]
# 可以通过使用del语句删除单个或多个对象。例如：

# %%
a = 32
del a
print(a)

# %% [markdown]
# ### 2.2.5　变量的存储

# %% [markdown]
# 一切变量都需要存储。变量的存储，采用了引用语义的方式，存储的只是一个变量的值所在的内存地址，而不是这个变量值本身。
# 语言的语义有两种形式：
# ①	引用语义：在Python中，变量保存的是对象(值)的引用，称为引用语义。采用这种方式，变量所需的存储空间大小一致，因为变量只是保存了一个引用。也被称为对象语义和指针语义。
# ②	值语义：有些语言采用的不是这种方式，它们把变量的值直接保存在变量的存储区里，这种方式被称之为值语义，例如C语言，采用这种存储方式，每一个变量在内存中所占的空间就要根据变量实际的大小而定，无法固定下来。
# 由于Python中的变量都是采用的引用语义，数据结构可以包含基础数据类型，导致了在Python中每个变量中都存储了这个变量的地址，而不是值本身；对于复杂的数据结构来说，里面的存储的也只是每个元素的地址而已。id()函数可以显示一个变量在内存中的地址，如下所示：

# %%
a = 123
b=123
print(id(a),id(b))
a = 456
print(id(a))

# %% [markdown]
# 在Python中是以数据为主，当给变量a赋值123后，再给a变量赋值456，不是说456这个数据把123这个数据给覆盖了，而是123和456在两个不同的内存空间上，只是把a这个变量名从123上移到了456上。如图2-1　数据的所示：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 同一个地址空间可以有两个变量名，甚至多个变量名，比如：

# %%
a = 123
print(id(a))
b = 123
print(id(b))
a = 456
print(id(a))
b = 456
print(id(b))

# %% [markdown]
# 上面的程序中，123这个数据的引用值是不变的，这就是为什么把123赋给b之后，b的引用值和原来一样的原因。如图2-2变量的引用所示：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 现在思考一个问题，如何实现两个变量值的互换？可以这么写：

# %%
a = 123
b = 456
c = a
a = b
b = c
print(a)
print(b)

# %% [markdown]
# 结果表明成功实现了两个值的互换，那么内存中发生了什么呢？

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 实际上，Python语言支持一种更方便的交换形式，如下：

# %%
a = 123
b = 456
a,b = b,a
print(a)
print(b)

# %% [markdown]
# ### 重新理解变量

# %%
test=int()
print(test)

# %% [markdown]
# 变量：指向对象的值的名称
# 变量是一个标识符，通过等号（=）赋值运算创建

# %% [markdown]
# ## 2.3数据类型

# %% [markdown]
# Python3中的数字类型包括int、float、bool、complex(复数)这几种。

# %%
a, b, c, d = 20, 5.5, True, 4+3j
print(type(a), type(b), type(c), type(d))

# %% [markdown]
# 此外还可以用 isinstance 来判断：

# %%
a = 111
b = isinstance(a, int)
print(b)

# %% [markdown]
# 需要指出的是，Python3中，把True和False定义成关键字了，它们的值实际上是1和0，它们可以和数字相加。表2-1给出了一些数字类型的实例。

# %% [markdown]
# 表2-1数字实例

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.3.1 int(整型)

# %% [markdown]
# 一个数的表示方式有几种常见的进制表示方式，分别是：二进制、八进制、十进制和十六进制。

# %%
a = 18
b = 0b110011
c = 0o54
d = 0xe4
print(a)
print(b)
print(c)
print(d)

# %% [markdown]
# ### 2.3.2 float(浮点型)

# %% [markdown]
# 浮点数也就是小数，之所以称为浮点数，是因为按照科学记数法表示时，一个浮点数的小数点位置是可变的，比如，1.23x109和12.3x108是完全相等的。
# 浮点数可以用数学写法，如1.23，3.14，-9.01，等等。但是对于很大或很小的浮点数，就必须用科学计数法表示，把10用e替代，1.23x10<sup>9</sup>就是1.23e9，或者12.3e8，0.000012可以写成1.2e-5，等等。
# 整数和浮点数在计算机内部存储的方式是不同的，整数运算永远是精确的（包括除法），而浮点数运算则可能会有四舍五入的误差。

# %% [markdown]
# ### 2.3.3 bool(布尔型)

# %% [markdown]
# 在Python中，可以直接用True、False表示布尔值（请注意大小写），也可以通过布尔运算计算出来。
# 在Python中，None、任何数值类型中的0、空字符串“”、空元组()、空列表[]、空字典{}都被当作False，还有自定义类型，如果实现了__ nonzero __ ()或__ len __ () 方法且方法返回 0 或False，则其实例也被当作False，其他对象均为True。

# %% [markdown]
# ### 2.3.4 complex(复数)

# %% [markdown]
# 复数由实数部分和虚数部分构成，可以用a+bj,或者complex(a,b)表示，复数的实部a和虚部b都是浮点型。如：3e+26j。

# %% [markdown]
# ### 2.3.5 空值

# %% [markdown]
# 空值是Python里一个特殊的值，用None表示。None不能理解为0，因为0是有意义的，而None是一个特殊的空值。
# 需要注意的是，None是一个特殊的常量。None和False不同。None不是0。None不是空字符串。None和任何其他的数据类型比较永远返回False。None有自己的数据类型NoneType。
# 编程者可以将None赋值给任何变量，但是不能创建其他NoneType对象。

# %%
a = None
print(a)
a is None

# %% [markdown]
# ## 2.4字符串类型

# %% [markdown]
#
# 字符串就是一系列字符。在Python中，用引号括起的都是字符串，其中的引号可以是单引号，也可以是双引号，如下所示：

# %%
"This is a string."
'This is also a string.'

# %% [markdown]
# 这种灵活性让编程者能够在字符串中包含引号和撇号：

# %%
test='this is \\n'
print(test)

# %%
'I told my friend, "Python is my favorite language!"'
"The language 'Python' is named after Monty Python, not the snake."
"One of Python's strengths is its diverse and supportive community."

# %% [markdown]
# Python不支持单字符类型，单字符在Python中也是作为一个字符串使用。

# %% [markdown]
# ## 2.5运算符与表达式

# %% [markdown]
# ### 2.5.1 运算符

# %% [markdown]
# Python语言支持以下类型的运算符:
# ①	算术运算符
# ②	比较（关系）运算符
# ③	赋值运算符
# ④	逻辑运算符
# ⑤	位运算符
# ⑥	成员运算符
# ⑦	身份运算符

# %% [markdown]
# #### 1．	算术运算符

# %% [markdown]
# 假设变量a为10，变量b为21

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/usr/bin/python3 
a = 21
b = 10
c = 0 
c = a + b
print ("1 - c 的值为：", c)
 
c = a - b
print ("2 - c 的值为：", c)
 
c = a * b
print ("3 - c 的值为：", c)
 
c = a / b
print ("4 - c 的值为：", c)
 
c = a % b
print ("5 - c 的值为：", c)
 
# 修改变量 a 、b 、c
a = 2
b = 3
c = a**b 
print ("6 - c 的值为：", c)
 
a = 10
b = 5
c = a//b 
print ("7 - c 的值为：", c)

# %% [markdown]
# #### 2．	比较运算符

# %% [markdown]
# 假设变量a为10，变量b为21：

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/usr/bin/python3
 
a = 21
b = 10
c = 0
 
print(a == b) 
print(a != b)
print(a < b)
print(a > b)
    
# 修改变量 a 和 b 的值
a = 5;
b = 20;
print(a <= b)   
print(b >= a)

# %% [markdown]
# #### 3．	逻辑运算符

# %% [markdown]
# 逻辑运算符主要用于逻辑运算

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/usr/bin/python3 
a = 10
b = 20
 
print(a and b) 
print(a or b)
 
# 修改变量 a 的值
a = 0
print(a and b) 
print(a or b)
print(not (a and b))

# %%
20
10
0
20
True

# %% [markdown]
# 短路逻辑：
# 在一个运算符的情况下，or从左到右，返回第一个为真的值，都为假返回后一个值，and从左到右，若所有值均为真，则返回后一个值，有一个假的值，则返回第一个假的值。
# 逻辑运算符and/or一旦不止一个，其运算规则的核心思想就是短路逻辑。短路思想具体如下：
# ①	表达式从左至右运算，若or的左侧逻辑值为True，则短路or后所有的表达式（不管是and还是or），直接输出or左侧表达式 。
# ②	表达式从左至右运算，若and的左侧逻辑值为False，则短路其后所有and表达式，直到有or出现，输出and左侧表达式到or的左侧，参与接下来的逻辑运算。
# ③	若or的左侧为False，或者and的左侧为True则不能使用短路逻辑。

# %%
a=2
b=3
print((a-2 and b+3))

# %%
print((a or b+3))

# %% [markdown]
# #### 4．	赋值运算符

# %% [markdown]
# 赋值运算符比较简单，主要用于赋值，可以将一个值或者一个变量甚至表达式赋给另一个变量。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/usr/bin/python3
a = 21
b = 10
c = 0
 
c = a + b
print ("1 - c 的值为：", c)
 
c += a
print ("2 - c 的值为：", c)
 
c *= a
print ("3 - c 的值为：", c)
 
c /= a 
print ("4 - c 的值为：", c)
 
c = 2
c %= a
print ("5 - c 的值为：", c)
 
c **= a
print ("6 - c 的值为：", c)
 
c //= a
print ("7 - c 的值为：", c)

# %% [markdown]
# #### 5．	位运算符

# %% [markdown]
# 按位运算符是把数字看作二进制来进行计算的。Python中的按位运算法则如下：
# 假定变量a为 60，b为13。

# %%
a = 0011 1100
b = 0000 1101

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/usr/bin/python3
a = 60            # 60 = 0011 1100 
b = 13            # 13 = 0000 1101 
c = 0
 
c = a & b;        # 12 = 0000 1100
print ("1 - c 的值为：", c)
 
c = a | b;        # 61 = 0011 1101 
print ("2 - c 的值为：", c)
 
c = a ^ b;        # 49 = 0011 0001
print ("3 - c 的值为：", c)
 
c = ~a;           # -61 = 1100 0011
print ("4 - c 的值为：", c)
 
c = a << 2;       # 240 = 1111 0000
print ("5 - c 的值为：", c)
 
c = a >> 2;       # 15 = 0000 1111
print ("6 - c 的值为：", c)

# %% [markdown]
# #### 6．	成员运算符

# %% [markdown]
# 除了以上的一些运算符之外，Python还支持成员运算符，用来检查某个序列中是否包含了某个成员，其中序列包括字符串、列表、元组、集合和字典等。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'a' in 'hello'

# %%
'ha' not in 'hello'

# %% [markdown]
# #### 7．	身份运算符

# %% [markdown]
# 身份运算符用于比较两个对象的存储单元。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/usr/bin/python3
a = 20
b = 20
 
if ( a is b ):
   print ("1 - a 和 b 有相同的标识")
else:
   print ("1 - a 和 b 没有相同的标识")
 
if ( id(a) == id(b) ):
   print ("2 - a 和 b 有相同的标识")
else:
   print ("2 - a 和 b 没有相同的标识")
 
# 修改变量 b 的值
b = 30
if ( a is b ):
   print ("3 - a 和 b 有相同的标识")
else:
   print ("3 - a 和 b 没有相同的标识")
 
if ( a is not b ):
   print ("4 - a 和 b 没有相同的标识")
else:
   print ("4 - a 和 b 有相同的标识")

# %% [markdown]
# is与==区别是：is用于判断两个变量引用对象是否为同一个，==用于判断引用变量的值是否相等。比如：

# %%
a = [1,2,3]
b = a
print(b is a)
print(b == a)
b = a[:]
print(b is a)
print(b == a)

# %% [markdown]
# #### 8．	运算符优先级

# %% [markdown]
# 从最高到最低优先级的所有运算符(同一行内，左边的优先级大于右边)：

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!/usr/bin/python3
 
a = 20
b = 10
c = 15
d = 5
e = 0
 
e = (a + b) * c / d       #( 30 * 15 ) / 5
print ("(a + b) * c / d 运算结果为：",  e)
 
e = ((a + b) * c) / d     # (30 * 15 ) / 5
print ("((a + b) * c) / d 运算结果为：",  e)
 
e = (a + b) * (c / d);    # (30) * (15/5)
print ("(a + b) * (c / d) 运算结果为：",  e)
 
e = a + (b * c) / d;      #  20 + (150/5)
print ("a + (b * c) / d 运算结果为：",  e)

# %% [markdown]
# ### 2.5.2 表达式

# %% [markdown]
# #### 1．	计算表达式

# %% [markdown]
# 和数学计算表达式一样，Python的计算表达式是由变量或者常量加上若干运算符组成的。例如下面的数学表达式：

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 可以转换为：
# (3+4*x)/5–10*(y-5)*(a+ b+ c)/x+9*(4/x+(9+x)/y)
# 首先执行括号内的运算符。括号可以为叠加，内层括号里的表达式首先被执行。
# 再来看一个逻辑表达式：
# year % 4 == 0 and year % 100 != 0 or year % 400 == 0
# 根据运算符优先级，or和and的优先级最低，所以程序会从左到右计算几个比较表达式的值，然后再计算逻辑值。

# %% [markdown]
# * 判断是否闰年
# 以year为2004为例，来看下计算流程：
# ①	year % 4 == 0 and year % 100 != 0 or year % 400 == 0
# ②	0 == 0 and 4 != 0 or 4 == 0
# ③	true and true or false
# ④	true or false
# ⑤	true
# 可以多用括号来确保某些部分优先执行：
# (year % 4 == 0 and year % 100 != 0) or year % 400 == 0

# %%
year=2000
print((year % 4 == 0 and year % 100 != 0 or year % 400 == 0))

# %% [markdown]
# #### 2．	类型转换

# %% [markdown]
# Python可以进行两种方式的类型转换：自动转换和强制转换。
# 1)自动转换
# 如果一个表达式里面有不同数字类型的值参与计算，那么Python会自动进行隐式类型转换。

# %%
a = True + 1 + 1.1 + (2 + 3j)
print(a)

# %% [markdown]
# 产生这样的结果的原因是，Python自动先将两个不同类型的数字变成同一种类型，然后再计算。比如True加上1，True是bool类型而1是int类型，True会被转换为1然后和1相加结果为2。下面是流程：
# ①	True + 1 + 1.1 + (2 + 3j)
# ②	1 + 1 + 1.1 + (2 + 3j)
# ③	2 + 1.1 + (2 + 3j)
# ④	2.0 + 1.1 + (2 + 3j)
# ⑤	3.1 + (2 + 3j)
# ⑥	(3.1 + 0j) + (2 + 3j)
# ⑦	5.1 + 3j
# 从上例可以看出，自动转换的优先级顺序是：
# Bool<Int<Float<Complex
# 2)强制转换
# 如果想要反其道而行，比如一个整数和一个浮点数相加，想得到整数结果，那么就要使用函数来进行强制类型转换。
# 1)	int(x [,base ])： 将x转换为一个整数；
# 2)	long(x [,base ])：将x转换为一个长整数；
# 3)	float(x )：将x转换到一个浮点数；
# 4)	complex(x [,imag])：将x转换到一个复数；
# 5)	hex()：转成十六进制；
# 6)	oct()：转成八进制；
# 7)	chr()：转成整数对应的ASCII字符；
# 8)	ord()：转成ASCII字符对应的整数；
# 9)	bin()：转成二进制；
# 来看一个简单的例子：

# %%
a = int(2.1)+3
print(a)

# %% [markdown]
# 这里，int(2.1)将浮点数2.1转为整数2，然后和3相加，结果为整数5。

# %% [markdown]
# #### *注意，Python不支持字符与数值相加或相减

# %% [markdown]
# ## 2.6 输出函数print()

# %% [markdown]
# ### 2.6.1 print()基本格式

# %% [markdown]
# 一般而言，print()函数只需要一个参数就可以输出一个对象了，而且这个对象可以是任意类型，包括列表、数字、字符串等等。比如：

# %%
print('Hello')
print(1)
print(True)
print([1,2,3])

# %% [markdown]
# 实际上，print()函数可以有多个参数，这些参数会首先全部转换为字符串，然后使用空格拼接起来，变成一个完整的字符串输出。比如：

# %%
print('Hello',"world",'!',1, True)

# %% [markdown]
# 所以编程者输出信息的时候，经常用两个参数，第一个参数是一个字符串，表达后面的内容的意义，后面的字符串负责输出内容。比如：

# %%
a = 1
b = 2
print(a + b)
print('a + b =',a + b)
print('a=',a," , b=",b)

# %% [markdown]
# ### 2.6.2 格式化输出

# %% [markdown]
# 有时普通输出的方式并不能满足编程者的要求，那就要对输出对象进行格式化：

# %% [markdown]
# (1)f-字符串

# %% [markdown]
# 用f修饰字符串，用{}括起变量

# %%
s0 = 'Hello world'
print('The string is %s'%s0)
x=2
print(f'The string is: {s0}, the variable is {x}')
# Out:
# The string is Hello world
# The string is: Hello world, the variable is 2

# %% [markdown]
# (2)字符串的 format() 方法
# 相对基本格式化输出采用‘%’的方法，format()功能更强大，该函数把字符串当成一个模板，通过传入的参数进行格式化，并且使用大括号‘{}’作为特殊字符代替‘%’
#
# 位置匹配:
# （1）不带编号，即“{}”
#
# （2）带数字编号，可调换顺序，即“{1}”、“{2}”
#
# （3）带关键字，即“{a}”、“{tom}”

# %%
print('字符串是 {}，整数变量是 {}，新增字符串是 {}'.format(s0,x,'Ni Hao'))

# %%
print('第2个是 {1}，第1个是 {0}，重复第2个 {1}'.format(s0,x))  #利用位置索引，注意顺序

# %%
print('整数变量是 {var},字符串是 {vstr}'.format(vstr=s0,var=x)) #利用关键字参数，可以变换顺序

# %%
print('{} {}'.format('hello','world'))  # 不带字段  hello world
print('{0} {1}'.format('hello','world'))  # 带数字编号   hello world
print('{0} {1} {0}'.format('hello','world'))  # 打乱顺序   hello world hello
print('{1} {1} {0}'.format('hello','world')) # world world hello
print('{a} {tom} {a}'.format(tom='hello',a='world'))  # 带关键字  world hello world

# %% [markdown]
# (3)传统格式化字符串方法 %

# %%
s0 = 'Hello world';x=2
print('The string is %s'%s0)
#x=2
print('The string is: %s, the variable is %d:'%(s0,x))

# %% [markdown]
# 这里的%s和%d都是转换说明符，实际输出的时候，%()里面的值将一定的格式替换前面字符串参数中的说明符。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 格式化字符串还需要一些辅助指令，置于%和说明符号之间

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 来看几个例子：

# %%
nHex = 0xFF
print("nHex = %x,nDec = % d,nOct = %o"%(nHex,nHex,nHex))
print("nHex = %#x,nDec = % d,nOct = %#o"%(nHex,nHex,nHex))

# %%
pi = 3.1415926535897932384626
print(pi)
print('%10.3f' % pi) #字段宽10，精度3  
print("pi = %.*f" % (3,pi)) #用*从后面的元组中读取字段宽度或精度  
print('%010.3f' % pi) #用0填充空白  
print('%-10.3f' % pi) #左对齐 
print('%+f' % pi) #显示正负号

# %% [markdown]
# ### 2.6.3 改变print()的自动换行

# %% [markdown]
# 在默认情况下，print()函数会自动在行末加上回车,如果不需回车，使用end参数，就可以改变它的行为。

# %%
print(0)
print(1)
print(2)
# Out:
# 0
# 1
# 2

# %% [markdown]
# 设置end参数

# %%
print(0,end='')
print(1,end='   ')
print(2,end=',')
print(3)
print(4)
# Out:
# 01   2,3
# 4

# %%
print('#',end='')
print('#',end='')
print('#',end='')
print('#',end='')
# Out:
# ####

# %% [markdown]
# ## 2.7 输入函数input()

# %% [markdown]
# 函数input()让程序暂停运行，等待用户输入一些文本。获取用户输入后，Python将其存储在一个变量中，以方便各位使用。

# %%
s = input()
print(s)

# %% [markdown]
# 这种获取用户的信息方式并不是很友好，因为用户不知道现在是等待用户输入状态。所以编程者可以给input()函数增加一个参数，用来提醒用户输入，比如：

# %%
s = input('请输入一个数值：')
print(s)

# %% [markdown]
# 要注意的是，无论用户输入的是什么信息，默认都是以字符串的形式被input()函数获取。比如：

# %%
s = input('请输入一个数值：')
print(type(s))

# %% [markdown]
# 当用户输入1，对象s对应的类型是：

# %%
请输入一个数值：1
<class 'str'>

# %% [markdown]
# 必要时，可以一次输入多个数据，输入时可使用空格、逗号等符号分隔，然后利用字符串方法提取每个输入

# %%
info = input('请输入学号和姓名，用空格分隔：')
stuid,name = info.split()
print(stuid)
print(name)

# %% [markdown]
# 注意，上例中stuid的类型仍然是字符串

# %% [markdown]
# 那如果编程者希望获取到的是一个整数，该怎么办呢？可以有两种方法：

# %% [markdown]
# ### 2.7.1 类型转换

# %% [markdown]
# 强制类型转换已在第二章介绍过，是一种比较简单的方式。比如：

# %%
s = int(input('请输入一个数值：'))
print(type(s))

# %%
s=input('请输入一个数值：')
num=int(s)
print(type(num))

# %% [markdown]
# 但是，如果此时用户输入的不是一个合法的数字，比如输入“a2”那么就会错：

# %%
ValueError: invalid literal for int() with base 10: 'a2'

# %% [markdown]
# #### *提问：如果输入3.14，能否得到整数3？

# %%
int(3.14)

# %%
num = int(input('请输入一个浮点数测试：'))
print(type(num))

# %%
int('3.14')

# %%
float('3.14')

# %% [markdown]
# #### 小技巧：自动类型转换

# %% [markdown]
# 自动转换通过一个函数eval()来实现，该函数可以自动识别出用户输入的数据类型，然后转换为对应的数据形式。比如：

# %%
s = input('请输入：')
a = eval(s)
print(type(a))
print(a)

# %%
a

# %% [markdown]
# 可以看出，eval()函数可以根据输入数据的类型自动转换。请注意，如果是字符串类型比如添加单引号或者双引号才行。

# %% [markdown]
# ## 2.8 常见内置函数

# %% [markdown]
# * eval() 函数
# 用来执行一个字符串形式的表达式，并返回表达式的值

# %%
'x+2'

# %%
x=2
eval('x+2')

# %% [markdown]
# 本章中已经介绍了用于计算的数学运算符，实现简单的加减乘除运算。Python中，还提供了如下一系列数学函数

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('abs(-2.3)=',abs(-2.3))
print(max(4, 3, -5))
print(min(5, 4, 6, 4, 0))
print(pow(3, 2))
print(round(4.345565, 2))
print(round(4.345565))

# %% [markdown]
# 另外，还有一些内置函数，可以为编程提供便利。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(id(5))
print(type('Hello'))
print(len('Hello'))
exit(0)

# %% [markdown]
# * 进制转换
# bin(),oct(),hex() #十进制数转为其他进制

# %%
print(bin(1023))
print(oct(16))
print(hex(255))

# %% [markdown]
# * 字符与ASCII的转换操作
# ord()返回一个字符对应的ascii码

# %%
print(ord('A'))
print(ord('a'))
print(ord('0'))
print(ord(' '))

# %% [markdown]
# chr()把一个范围在0～255内的整数转换为一个对应的字符

# %%
print(chr(0))  #对应'\0'
print(chr(255))
print(chr(65+32))
print(chr(ord('f')-32))

# %% [markdown]
# ## 2.9应用实例

# %% [markdown]
# 从本章开始，大部分章节最后都会通过一个家用电器销售系统的实际应用来尽可能地涵盖本章覆盖的知识点。当然，由于目前讲解的知识还非常有限，所以功能也不会很完善。家用电器销售系统第一版（v1.0）实现的功能是列出系统内可以销售的产品，并给出每个产品的具体信息，然后用户输入所选商品的编号，价格和数量，系统将自动计算用户需要支付多少金额。
# 	下面给出家用电器销售系统的代码：

# %%
"""
家用电器销售系统
v1.0
"""

# 欢迎信息
print('欢迎使用家用电器销售系统！')

# 产品信息列表
print('产品和价格信息如下：')
print('*********************************************************')
print('%-10s' % '编号', '%-10s' % '名称', '%-10s' % '品牌', '%-10s' % '价格', '%-10s' % '库存数量')
print('---------------------------------------------------------')
print('%-10s' % '0001', '%-10s' % '电视机', '%-10s' % '海尔', '%10.2f' % 5999.00, '%10d' % 20)
print('%-10s' % '0002', '%-10s' % '冰箱', '%-10s' % '西门子', '%10.2f' % 6998.00, '%10d' % 15)
print('%-10s' % '0003', '%-10s' % '洗衣机', '%-10s' % '小天鹅', '%10.2f' % 1999.00, '%10d' % 10)
print('%-10s' % '0004', '%-10s' % '空调', '%-10s' % '格力', '%10.2f' % 3900.00, '%10d' % 0)
print('%-10s' % '0005', '%-10s' % '热水器', '%-10s' % '美的', '%10.2f' % 688.00, '%10d' % 30)
print('%-10s' % '0006', '%-10s' % '笔记本', '%-10s' % '联想', '%10.2f' % 5699.00, '%10d' % 10)
print('%-10s' % '0007', '%-10s' % '微波炉', '%-10s' % '苏泊尔', '%10.2f' % 480.50, '%10d' % 33)
print('%-10s' % '0008', '%-10s' % '投影仪', '%-10s' % '松下', '%10.2f' % 1250.00, '%10d' % 12)
print('%-10s' % '0009', '%-10s' % '吸尘器', '%-10s' % '飞利浦', '%10.2f' % 999.00, '%10d' % 9)
print('---------------------------------------------------------')

# 用户输入信息
product_id = input('请输入您要购买的产品编号：')
price = float(input('请输入您要购买的产品价格：'))
count = int(input('请输入您要购买的产品数量：'))

# 计算金额
print('购买成功，您需要支付', price * count, '元')

# 退出系统
print('谢谢您的光临，下次再见！')

# %% [markdown]
# ## 本章小结

# %% [markdown]
# * 本章主要讲解了Python基础语法知识，包括变量的概念，基本数据类型，算数表达式和常见的运算符号，这些是进一步学习编程知识的基础。
# * 要特别注意变量类型以及类型转换的方法，会是一个很有用的编程技巧。
# * 介绍了适合输入、输出的基本方法，和一些常用的内置函数，以便能够编码实现一些基础功能。
