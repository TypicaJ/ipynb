# %% [markdown]
# # 第6章　元组、集合、字典

# %% [markdown]
# ## 6.1　导学

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 学习目标：
# 1.	掌握元组、集合和字典的创建方法
# 2.	掌握元组、集合和字典中的常见操作
# 3.	掌握元组、集合和字典中的元素遍历
# 4.	理解三种结构的性能区别
# 5.	掌握三种结构的比较
# 6.	了解如何使用字典开发应用程序
#
# 重点：三种结构的创建方法和常见操作
#
# 难点：字典的遍历

# %% [markdown]
# ## 6.2　元组

# %% [markdown]
# Python中不能修改的类型称为不可变数据类型，而不可变的列表被称为元组。

# %% [markdown]
# ### 6.2.1　元组定义

# %% [markdown]
# 元组名 = （元素1，元素2，…元素n）

# %%
tup1 = (1, 2, 3)
tup2 = (1.2, 0.0, 4.8)
tup3 = ('a','b','c','d')
ls=[1,2,3]
print(ls)
print(tup1)
# Out:
# [1, 2, 3]
# (1, 2, 3)

# %% [markdown]
# 元组中的元素的数据类型可以不一样

# %%
tup = ('1', 2, True)

# %% [markdown]
# 元组的括号也可以省略

# %%
tup = '1', 2, True

# %% [markdown]
# 元组中也可以没有任何元素，此时该元组称为空元组

# %%
tup = ()

# %% [markdown]
# * 注意注意：元组中只包含一个元素时，需要在元素后面添加逗号
# 否则在某些场景下可能导致隐性错误，例如作为函数参数传递

# %%
tup1 = (50)
print(type(tup1))  # 不加逗号，类型为整型
tup2 = (50,)
print(type(tup2))  # 加上逗号，类型为元组
# Out:
# <class 'int'>
# <class 'tuple'>

# %% [markdown]
# ### 6.2.2　访问元组

# %% [markdown]
# 元组中元素访问通过下标获取

# %%
tup = ('Google', 'Runoob', 1997, 2000)
print("tup[0]: ", tup[0])
# Out:
# tup[0]:  Google

# %% [markdown]
# 元组中元素访问也可以通过下标的切片获取元组中一部分

# %%
tup = (1, 2, 3, 4, 5, 6, 7)
print("tup[1:5]: ", tup[1:5])
# Out:
# tup[1:5]:  (2, 3, 4, 5)

# %% [markdown]
# ### 6.2.3　修改元组

# %% [markdown]
# 元组中的值是不可以修改

# %%
s='123'
#s[0]='3'
tup = ('Google', 'Runoob', 1997, 2000)
tup[0] = 'baidu'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MINGLI~1\AppData\Local\Temp/ipykernel_15968/3787079936.py in <module>
#       2 #s[0]='3'
#       3 tup = ('Google', 'Runoob', 1997, 2000)
# ----> 4 tup[0] = 'baidu'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# 但是，元组支持连接操作

# %%
tup1 = (1,2)
tup2 = (3,4)
print(tup1 + tup2)
print(tup1*3)
# Out:
# (1, 2, 3, 4)
# (1, 2, 1, 2, 1, 2)

# %% [markdown]
# ### 6.2.4　删除元组

# %% [markdown]
# 元组中的值是不可以修改，所以也不可以被删除，在第二章中介绍过，使用del语句可以删除一个变量，如果使用它修改元组元素

# %%
tup = ('Google', 'Runoob', 1997, 2000)
del tup[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\MINGLI~1\AppData\Local\Temp/ipykernel_15968/503568174.py in <module>
#       1 tup = ('Google', 'Runoob', 1997, 2000)
# ----> 2 del tup[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# 元组支持使用del语句，将整个元组删除掉

# %%
tup = ('Google', 'Runoob', 1997, 2000)
del tup

#tup=()
print(tup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c55eeca4af57> in <module>()
#       3
#       4 #tup=()
# ----> 5 print(tup)
#
# NameError: name 'tup' is not defined

# %% [markdown]
# ### 6.2.5　元组内置函数

# %% [markdown]
# 1．	len(tuple)
# 该函数返回元组中的元素个数

# %%
tup = ('Google', 'Runoob', 1997, 2000)
print(len(tup))
# Out:
# 4

# %% [markdown]
# 2．	max(tuple)
# 该函数可以获取元组中最大值

# %%
tup = (1,3,4,-5,0,8)
print(max(tup)) 
max('acb','aba')
# Out:
# 8
# 'acb'

# %% [markdown]
# 3．	min(tuple)
# 该函数可以获取元组中最小值

# %%
tup = (1,3,4,-5,0,8)
print(min(tup))

# %% [markdown]
# 4．	tuple(seq)
# 该函数可以将其它序列转换为元组

# %%
list = [1,3,4,-5,0,8,0]
str = 'Hello'
set = {1,2,3}
dic = {'name':'whb','age':12}
print(tuple(list))
print(tuple(str))
print(tuple(set))
print(tuple(dic))
# Out:
# (1, 3, 4, -5, 0, 8, 0)
# ('H', 'e', 'l', 'l', 'o')
# (1, 2, 3)
# ('name', 'age')

# %% [markdown]
# ### 6.2.6　元组的遍历

# %% [markdown]
# 元组的遍历从头到尾依次从元组中获取数据

# %%
tup = ("zhangsan",18,1.75)
for item in tup:
    print(item)
# Out:
# zhangsan
# 18
# 1.75

# %% [markdown]
# ### 6.2.7 元组的封装和解封

# %% [markdown]
# 元组封装（sequence packing）

# %%
t = 12345,54321,'hello!' 
print(t)
# Out:
# (12345, 54321, 'hello!')

# %% [markdown]
# 逆操作，解封（同样适用于列表）

# %%
t = 1, 2,3     #封装
x, y,z = t       #解封
#x, y,_ = t       #解封
print(x, y,z)
# Out:
# 1 2

# %% [markdown]
# 应用：变量交换

# %%
x=3;y=4
print(x,y)
x,y = y,x
print(x,y)
# Out:
# 3 4
# 4 3

# %% [markdown]
# ## 6.3　集合

# %% [markdown]
# 集合与列表类似，可以用来存储一个元素集合。但是集合的显著特点是，元素是没有顺序的，并且不可以重复，集合的概念和特点和数学中学到的集合概念是一样的

# %% [markdown]
# ### 6.3.1　创建集合

# %% [markdown]
# 方式1：set()函数可以创建一个集合，其格式如下： 集合名 = set（[迭代对象]）

# %%
num =set(["hello","world","of","words","of","world"])  
print(num)

num1=set('123')
print(num1)
# Out:
# {'hello', 'world', 'words', 'of'}
# {'2', '3', '1'}

# %% [markdown]
# 方式2：使用花括号创建集合是一种常见的创建方式，格式为：
# 集合名 = {元素1，元素2，元素3，...}

# %%
num = {1, 2, 3}
fruit = {'apple', 'orange', 'apple', 'pear', 'orange', 'banana'}
print(num)
print(fruit)
# Out:
# {1, 2, 3}
# {'banana', 'pear', 'orange', 'apple'}

# %% [markdown]
# 一个错误的示范
# 创建空集合

# %%
num = {}
print(type(num))
# Out:
# <class 'dict'>

# %% [markdown]
# 此时的结果是一个字典，而不是集合。如果要创建空的集合，必须使用set()函数来创建.

# %%
num = set()
print(type(num))
# Out:
# <class 'set'>

# %% [markdown]
# 如果创建非空集合，可以在set()函数中添加元素，用逗号隔开

# %%
num3 = set('123')
print(num3)
# Out:
# {'3', '1', '2'}

# %% [markdown]
# 字符串作为函数的参数传入，set()函数将其转换为集合。此时，多执行几次程序，就会发现每次程序的输出结果中，元素的次序有可能不同，这是集合中元素没有次序所致。

# %% [markdown]
# 除了字符串外，还可以用其他可迭代数据类型生成集合元素

# %%
num1 = set((1, 2, 3))       #元组
num2 = set('abcdefg')           #字符串
num3 = set()
num4 = set([1, 2, 3])      #列表
num5 = set({})                #字典

# %% [markdown]
# set()函数还支持使用迭代表达式来创建集合

# %%
num = set(x * 4 for x in range(1, 8, 2))
print(num)
# Out:
# {20, 28, 4, 12}

# %% [markdown]
# 在做转换时，如果有重复元素，set()函数会自动将重复元素去掉。因此，可以使用这种方法来完成消重。

# %%
Ls1 = [1,3,5,3,7,4,5]
Ls2 = list(set(Ls1))
print(Ls2)
# Out:
# [1, 3, 4, 5, 7]

# %% [markdown]
# 和列表类似，一个集合可以包含类型相同或者不同的元素。

# %%
num1 = {1, True, '3',['a', 3.4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-38e5789eb62a> in <module>()
# ----> 1 num1 = {1, True, '3',['a', 3.4]}
#
# TypeError: unhashable type: 'list'

# %%
这就是一个包含了各种元素类型的集合。实际上，因为元素必须不
同，集合中的每个元素都必须是可哈希的（即集合中元素必须是不
可变类型），而list是可变数据类型，因此不能作为集合的的元素

# %% [markdown]
# ### 6.3.2　集合运算符

# %% [markdown]
# 集合经常用来实现一些集合之间的运算，可以使用集合运算符来实现
# 并|、交&、差-、对称差集^（并集-交集）

# %%
a = set('abracadabra')
b = set('alacazam')
print(a)
print(b)
print(a | b)    # 集合a或b中包含的所有元素
print(a & b)  # 集合a和b中都包含了的元素
print(a - b)    # 集合a中包含而集合b中不包含的元素
print(a ^ b)    # 不同时包含于a和b的元素
# Out:
# {'a', 'b', 'c', 'd', 'r'}
# {'z', 'm', 'l', 'a', 'c'}
# {'z', 'm', 'l', 'a', 'b', 'c', 'd', 'r'}
# {'a', 'c'}
# {'d', 'b', 'r'}
# {'b', 'd', 'z', 'm', 'r', 'l'}

# %% [markdown]
# 列表中支持的in和not in运算符也可以用于集合中

# %%
s = set('Hello')#
print(s)
print('e' in s)
print('c' not in s)
# Out:
# {'H', 'l', 'o', 'e'}
# True
# True

# %% [markdown]
# 使用运算符==和!=来判断两个集合中是否包含相同的元素

# %%
x = {1, 2, 3}
y = {1, 3, 2}
print(x == y)
print(x != y)
Here
# Out:
# True
# False

# %% [markdown]
# 尽管两个集合中相同元素出现的顺序不同，不会影响两个集合的相等比较。集合可以使用大于（>）、小于（<）、大于等于（>=）、小于等于（<=）来判断某个集合是否完全包含于另一个集合，也可以使用子父集判断函数。
# 子集（>=）：子集是一个数学概念:如果集合A的任意一个元素都是集合B的元素，那么集合A称为集合B的子集。
# 真子集（>）：如果集合A的任意一个元素都是集合B的元素，且集合A不等于集合B，那么集合A称为集合B的子集。

# %%
s1 = set([1, 2, 3, 4, 5])
s2 = set([1, 2, 3, 4])
s3 = set([1, 2, 3, 4])
print(s1 > s2)
print(s2 >= s3)
print(s2 < s1)
print(s3 <= s1)
# Out:
# True
# True
# True
# True

# %% [markdown]
# ### 6.3.3　集合基本函数

# %% [markdown]
# 1．	集合基本操作
# 和列表一样，集合也可以使用函数len,min,max和sum等对集合进行常见的操作

# %%
num = {3, 1, 2}
length = len(num)
max_value = max(num)
min_value = min(num)
sum_value = sum(num)
print(length)
print(max_value)
print(min_value)
print(sum_value)
print(sum([1,2,3,4]))
# Out:
# 3
# 3
# 1
# 6
# 10

# %% [markdown]
# 也可以使用for循环来遍历集合中每一个元素

# %%
num = {3, 1, 2}
for x in num:
    print(x)
# Out:
# 1
# 2
# 3

# %% [markdown]
# 2．	添加元素
# 集合拥有方法add()可以将元素添加到集合中，如果元素已经存在，则不进行任何操作。

# %%
num = {1, 2, 3}
num.add(4)
print(num)
num.add(3)
print(num)
# Out:
# {1, 2, 3, 4}
# {1, 2, 3, 4}

# %% [markdown]
# 还有一个方法update()也可以添加元素，且参数可以是列表，元组，字典等。

# %%
num = {1, 2, 3}
num.update([4])
print(num)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# 3．	移除元素
# 集合拥有方法remove()可以将集合中的某个元素移除

# %%
num = {1, 2, 3}
num.remove(3)
print(num)
# Out:
# {1, 2}

# %% [markdown]
# 但是，如果移除的元素不存在，比如将上例中的3改为4，则会报如下异常

# %%
num = {1, 2, 3}
num.remove(4)
print(num)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\MINGLI~1\AppData\Local\Temp/ipykernel_14952/1683183339.py in <module>
#       1 num = {1, 2, 3}
# ----> 2 num.remove(4)
#       3 print(num)
#
# KeyError: 4

# %% [markdown]
# 还有一个方法discard()也可以移除元素

# %%
num = {1, 2, 3}
num.discard(2)
print(num)

# %% [markdown]
# 和remove()不同的是，discard()在元素不存在的情况下，并不会报错。

# %% [markdown]
# 函数pop()也可以用来随机删除一个集合元素，集合自带的pop()是删除集合的第一个元素（排序后的集合的第一个元素）

# %%
num = {3, 1, 2}
print(num)
a = num.pop()
print(a)
a =[1,2,3]
b = a.pop()
print(b)
# Out:
# {1, 2, 3}
# 1
# 3

# %% [markdown]
# 函数clear()可以将所有元素清空

# %%
num = {3, 1, 2}
num.clear()
print(num)
del num
print(num)
# Out:
# set()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MINGLI~1\AppData\Local\Temp/ipykernel_14952/3524273968.py in <module>
#       3 print(num)
#       4 del num
# ----> 5 print(num)
#
# NameError: name 'num' is not defined

# %% [markdown]
# 4．	集合关系的判断
# 集合的方法issubset()可以判断当前集合是否为指定集合（该方法参数）的子集

# %%
x = {"a", "b", "c"}
y = {"f", "e", "d", "c", "b", "a"}
print(x.issubset(y))
# Out:
# False

# %% [markdown]
# issuperset() 方法用于判断当前集合是否为指定集合的超集，即当前集合包含指定集合，如果是则返回 True，否则返回 False。

# %%
x = {"f", "e", "d", "c", "b", "a"}
y = {"a", "b", "c"}
print(x.issuperset(y))
# Out:
# True

# %% [markdown]
# 集合里的union() 方法返回两个集合的并集，即包含了所有集合的元素，重复的元素只会出现一次

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "runoob", "apple"}
z = x.union(y)
print(z)
# Out:
# {'google', 'banana', 'apple', 'runoob', 'cherry'}

# %% [markdown]
# intersection() 方法用于返回两个或更多集合中都包含的元素，即交集。该方法返回一个新集合，该集合的元素存在于两个集合中。

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "runoob", "apple"}
z = x.intersection(y)
print(z)
# Out:
# {'apple'}

# %% [markdown]
# difference() 方法用于返回集合的差集，即返回的集合元素包含在第一个集合中，但不包含在第二个集合(方法的参数)中。

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "runoob", "apple"}
z = x.difference(y)
print(z)
# Out:
# {'cherry', 'banana'}

# %% [markdown]
# ## 概括——序列对象

# %% [markdown]
# 字符串、列表和元组的对象类型均属于序列对象, 可使用数字索引访问其中元素的对象
# 拥有一些共同特性和操作方法

# %% [markdown]
# * 可用算术运算符联接或重复序列。 (+/*)
# * 可使用比较运算符(<，<=，>，>=，!=，==)
# * 可通过下标，切片和解封来访问序列的某部份
# * in运算符可判断当有对象是否序列对象成员
# * 可通过循环运算符对序列对象进行迭代操作

# %% [markdown]
# ## 6.4　字典

# %% [markdown]
# 字典是一个比较特殊的数据表示形式。通过使用字典，能更准确地为各种真实物体建模。比如创建一个表示人的字典，然后存储姓名、年龄、地址、职业以及要描述的任何类型信息。还能够存储任意两种相关的信息，如单词及其解释意义，物种及其描述，食物名称和属性等。

# %% [markdown]
# ### 6.4.1　创建字典

# %% [markdown]
# 字典是由一系列键-值对组成的。每个键都与一个值相关联，便可以使用键来访问与之相关联的值。与键相关联的值可以是数字、字符串、列表乃至字典。事实上，可将任何Python对象用作字典中的值。
#
#
# 在Python中，字典用放在花括号{}中的一系列键-值对表示，格式为：
#
# 字典名 = {键1：值1，键2：值2，...}

# %%
fruit = ['apple', 'orange', 'pear', 'banana']
num = [1, 2, 3,  2]

# %% [markdown]
# 但若使用字典，可以将其合并

# %%
fruit_num = {'apple': 1, 'orange': 2, 'banana':3, 'apple':2}

# %% [markdown]
# 字典的结构和前面的数据结构都不同，是由一个个的键值对组成的。相当于给每个信息加上了一个独一无二的名称。
# 一个字典中，键和值的类型都可以不一样。

# %%
any_type = {'Hi': [4,9.0], 2: 8, True: {'Hello'}, 5.00: '122'}

# %% [markdown]
# 键和值都可以重复，如果键重复，后一个有效。在键不重复的情况下，值重复是正常的

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10, 'apple': 5}
print(fruit_num['apple'])
print(fruit_num['orange'])
# Out:
# 5
# 8

# %% [markdown]
# 键必须不可变，所以可以用数字，字符串或元组充当，不能用字典、列表、集合以及内部至少带有上述三种类型之一的元组等作为键

# %%
fruit_num = {['apple']: 2, 'orange': 8, 'banana': 10}   # 出错，列表可变
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-b12939e7d598> in <module>()
# ----> 1 fruit_num = {['apple']: 2, 'orange': 8, 'banana': 10}   # 出错，列表可变
#
# TypeError: unhashable type: 'list'

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10, {1:2}: 5}   # 出错，字典可变

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10, (2,3): 5}   # 正确，元组不可变

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10, (2,{}): 5}   #出错，元组不可变，但含有可变类型

# %% [markdown]
# 原因：
# * Python中，字典也就是一个个的“映射”，将键映射到值， 对一个特定的键可以得到一个值。为了实现这个功能，Python必须能够做到，给出一个键，找到哪一个值与这个键对应。
# * 一种办法是将所有的键值对存放到一个列表中，每当需要的时候，就去遍历这个列表，如果找到键，就拿到值，但是这种实现在数据量很大的时候就变得很低效。
# * Python使用了hash（哈希）的方法来实现，要求每一个存放到字典中的对象都要实现哈希函数，这个函数可以产生一个int值，叫做hash value（哈希值），通过这个int值，就可以快速确定对象在字典中的位置。而列表、集合和字典是不能哈希的。

# %% [markdown]
# ### 6.4.2　字典元素的操作

# %% [markdown]
# 1．	字典的元素读取
#
# 字典的值读取可以通过相应的键作为标记来获取值。
#
# 格式如下：
# 值 = 字典名[键]

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(fruit_num['apple'])
# Out:
# 2

# %% [markdown]
# 如果键不存在

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10 }  #出错
print(fruit_num['pear'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\MINGLI~1\AppData\Local\Temp/ipykernel_14952/629171442.py in <module>
#       1 fruit_num = {'apple': 2, 'orange': 8, 'banana': 10 }  #出错
# ----> 2 print(fruit_num['pear'])
#
# KeyError: 'pear'

# %% [markdown]
# 另一种方法是使用get(key，[default])函数，第一个参数为key，第二参数为键不存在获取不到值返回的默认值，可缺省。

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(fruit_num.get('orange'))
print(fruit_num.get('paek','ok'))
# Out:
# 8
# ok

# %% [markdown]
# 但如果执行

# %%
print(fruit_num.get('pear'))
# Out:
# None

# %% [markdown]
# 如果不希望返回None，而是返回一个默认值，就可以添加第二个参数

# %%
print(fruit_num.get('pear', 0))

# %% [markdown]
# 还可以使用setdefault(key，[default])函数来读取某个键的值

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(fruit_num.setdefault('orange',5))
# Out:
# 8

# %% [markdown]
# 2．	字典的元素修改
#
# 修改字典中值的方法也很简单，只需要根据字典的键来获取就行
#
# 格式如下：
# 字典名[键] = 新值

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
fruit_num['apple'] = 4
print(fruit_num)
# Out:
# {'apple': 4, 'orange': 8, 'banana': 10}

# %% [markdown]
# 也可以使用update()函数来进行值的修改，update()方法来使用一个新的字典来修改旧的字典对应元素值

# %%
fruit_num1 = {'apple': 2, 'orange': 8, 'banana': 10}
fruit_num2 = {'apple': 4, 'orange': 2, 'pear': 3}
fruit_num1.update(fruit_num2)
print(fruit_num1)
# Out:
# {'apple': 4, 'orange': 2, 'banana': 10, 'pear': 3}

# %% [markdown]
# 还可以使用setdefault(key，[default])函数来读取某个键的值

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(fruit_num.setdefault('orange'))
print(fruit_num.setdefault('peak',5))
print(fruit_num)
# Out:
# 8
# 5
# {'apple': 2, 'orange': 8, 'banana': 10, 'peak': 5}

# %% [markdown]
# 3．	字典的元素添加
#
#
#
#
#
#
# 第一种添加新元素的方式很简单，只要给一个当前字典不存在的键的元素赋值就会添加新元素

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
fruit_num['pear'] = 56
print(fruit_num)

# %% [markdown]
# 第二种方法仍然使用setdefault(key，[default])函数，如果key不存在，就会添加新元素。

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
fruit_num.setdefault('pear', 23)
print(fruit_num)
fruit_num.setdefault('apple', 23)
print(fruit_num)
# Out:
# {'apple': 2, 'orange': 8, 'banana': 10, 'pear': 23}
# {'apple': 2, 'orange': 8, 'banana': 10, 'pear': 23}

# %% [markdown]
# 和get()函数一样，如果setdefault()函数没有给出default值，则会使用None作为值

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
fruit_num.setdefault('pear')
print(fruit_num)
# Out:
# {'apple': 2, 'orange': 8, 'banana': 10, 'pear': None}

# %% [markdown]
# 4．	字典的元素删除
#
# 如果要删除一个元素，可以使用del语句

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
del fruit_num['apple']
print(fruit_num)
# Out:
# {'orange': 8, 'banana': 10}

# %% [markdown]
# 可以使用del语句来删除整个字典

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
del fruit_num
print(fruit_num)

# %% [markdown]
# 第二个办法是使用pop(key)函数，用来删除key对应的元素，并返回该元素的值。

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(fruit_num.pop('banana'))
print(fruit_num)
# Out:
# 10
# {'apple': 2, 'orange': 8}

# %% [markdown]
# 第三个办法是使用popitem()函数，和pop()函数不同的是，这个函数只能删除最后一个元素，返回该元素。

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(fruit_num.popitem())
print(fruit_num)
# Out:
# ('banana', 10)
# {'apple': 2, 'orange': 8}

# %% [markdown]
# 如果想要清空所有元素，可以使用clear()函数

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
fruit_num.clear()
print(fruit_num)
# Out:
# {}

# %% [markdown]
# 5．	字典的其它操作
#
# 1）	字典的信息获取
#
# len(dict)获取字典元素个数

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(len(fruit_num))
# Out:
# 3

# %% [markdown]
# items()、keys()和values()三个函数分别得到所有的项、键和值

# %%
fruit_num = {'apple': 2, 'orange': 8, 'banana': 10}
print(fruit_num.items())
print(fruit_num.keys())
print(fruit_num.values())
# Out:
# dict_items([('apple', 2), ('orange', 8), ('banana', 10)])
# dict_keys(['apple', 'orange', 'banana'])
# dict_values([2, 8, 10])

# %% [markdown]
# 遍历字典

# %%
for key, value in fruit_num1.items():
    print(key,value)
# Out:
# apple 4
# orange 2
# banana 10
# pear 3

# %% [markdown]
# 2）	字典拷贝
#
# 字典的拷贝可以使用copy()函数，此拷贝是浅拷贝

# %%
fruit_num1 = {'name': 2, 'age': 8, 'banana': 10,'ids':[1,2,3]}
fruit_num2 = fruit_num1.copy()  # 浅拷贝：深拷贝父对象（一级目录），子对象（二级目录）不拷贝，还是引用
print(id(fruit_num2),id(fruit_num1))
fruit_num1['name']=1
fruit_num1['ids'].append(4)
print('fruit_num1=',fruit_num1)
print('fruit_num2=',fruit_num2)
fruit_num2.clear()
print('fruit_num1',fruit_num1)
print('fruit_num2=',fruit_num2)
# Out:
# 2366545808048 2366546494088
# fruit_num1= {'name': 1, 'age': 8, 'banana': 10, 'ids': [1, 2, 3, 4]}
# fruit_num2= {'name': 2, 'age': 8, 'banana': 10, 'ids': [1, 2, 3, 4]}
# fruit_num1 {'name': 1, 'age': 8, 'banana': 10, 'ids': [1, 2, 3, 4]}
# fruit_num2= {}

# %% [markdown]
# 需要注意复制和赋值的区别

# %%
fruit_num1 = {'name': 2, 'age': 8, 'banana': 10}
fruit_num2 = fruit_num1   # 浅拷贝: 引用对象
print(fruit_num2)
fruit_num2.clear()
print(fruit_num2)   
print(fruit_num1)
# Out:
# {'name': 2, 'age': 8, 'banana': 10}
# {}
# {}

# %% [markdown]
# ### 6.4.3　字典和其它序列类型的区别

# %% [markdown]
# * 列表是动态数组，可变且可以重设长度（改变其内部元素的个数）。元组是静态数组，不可变，且其内部数据一旦创建便无法改变。也不能追加元素，弹出元素等。
# * 元组缓存于Python运行时环境，每次使用元组时无须访问内核去分配内存。所以，元组是不能改变长度的列表。如果元素不需要改变值，比如常量、不可变参数，可以使用元组。使用元组的好处在于对元组进行操作更为高效。
# * 字典的查找和插入的速度极快，不会随着key的增加而变慢。但是需要占用大量的内存，内存浪费多。相反，列表查找和插入的时间随着元素的增加而增加。但是占用空间小，浪费内存很少。
# * 字典的key不可以是可变对象，因为无法判断两个可变对象是否相等，也就无法保证内部“不会有重复元素”。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6.5 应用实例

# %% [markdown]
# 电器系统里面用来表示商品，使用的是列表。但是从程序可读性来说，这种做法并不是很好的选择，因为类似于products[i][2]这样的表达方式，大家不容易知道是哪个商品属性。所以，本节将修改商品数据结构，使用字典来表示每个商品，根据这样的需求，新版本的程序代码如下

# %%
"""
家用电器销售系统
v1.4
"""

# 欢迎信息
print('欢迎使用家用电器销售系统！')

# 商品数据初始化
products = [
    {'id': '0001', 'name': '电视机', 'brand': '海尔', 'price': 5999.00, 'count': 20},
    {'id': '0002', 'name': '冰箱', 'brand': '西门子', 'price': 6998.00, 'count': 15},
    {'id': '0003', 'name': '洗衣机', 'brand': '小天鹅', 'price': 1999.00, 'count': 10},
    {'id': '0004', 'name': '空调', 'brand': '格力', 'price': 3900.00, 'count': 0},
    {'id': '0005', 'name': '热水器', 'brand': '格力', 'price': 688.00, 'count': 30},
    {'id': '0006', 'name': '笔记本', 'brand': '联想', 'price': 5699.00, 'count': 10},
    {'id': '0007', 'name': '微波炉', 'brand': '苏泊尔', 'price': 480.00, 'count': 33},
    {'id': '0008', 'name': '投影仪', 'brand': '松下', 'price': 1250.00, 'count': 12},
    {'id': '0009', 'name': '吸尘器', 'brand': '飞利浦', 'price': 999.00, 'count': 9},
]

# 初始化用户购物车
products_cart = []

option = input('请选择您的操作：1-查看商品；2-购物；3-查看购物车；其它-结账')
while option in ['1', '2', '3']:
    if option == '1':
        # 产品信息列表
        print('产品和价格信息如下：')
        print('**************************************************')
        print('%-10s' % '编号', '%-10s' % '名称', '%-10s' % '品牌', '%-10s' % '价格', '%-10s' % '库存数量')
        print('-------------------------------------------------')
        for i in range(len(products)):
            print('%-10s' % products[i]['id'], '%-10s' % products[i]['name'],
                  '%-10s' % products[i]['brand'],
                  '%10.2f' % products[i]['price'], '%10d' % products[i]['count'])
        print('-------------------------------------------------')
    elif option == '2':
        product_id = input('请输入您要购买的产品编号：')
        while product_id not in [item['id'] for item in products]:
            product_id = input('编号不存在，请重新输入您要购买的产品编号：')

        count = int(input('请输入您要购买的产品数量：'))
        while count > products[int(product_id) - 1]['count']:
            count = int(input('数量超出库存，请重新输入您要购买的产品数量：'))

        # 将所购买商品加入购物车
        if product_id not in [item['id'] for item in products_cart]:
            products_cart.append({'id': product_id, 'count': count})
        else:
            for i in range(len(products_cart)):
                if products_cart[i].get('id') == product_id:
                    products_cart[i]['count'] += count

        # 更新商品列表
        for i in range(len(products)):
            if products[i]['id'] == product_id:
                products[i]['count'] -= count
    else:
        print('购物车信息如下：')
        print('***************************')
        print('%-10s' % '编号', '%-10s' % '购买数量')
        print('---------------------------')
        for i in range(len(products_cart)):
            print('%-10s' % products_cart[i]['id'], '%6d' % products_cart[i]['count'])
        print('---------------------------')
    option = input('操作成功！请选择您的操作：1-查看商品；2-购物；3-查看购物车；其它-结账')

# 计算金额
if len(products_cart) > 0:
    amount = 0
    for i in range(len(products_cart)):
        product_index = 0
        for j in range(len(products)):
            if products[j]['id'] == products_cart[i]['id']:
                product_index = j
                break
        price = products[product_index]['price']
        count = products_cart[i]['count']
        amount += price * count

    if 5000 < amount <= 10000:
        amount = amount * 0.95
    elif 10000 < amount <= 20000:
        amount = amount * 0.90
    elif amount > 20000:
        amount = amount * 0.85
    else:
        amount = amount * 1
    print('购买成功，您需要支付%8.2f元' % amount)

# 退出系统
print('谢谢您的光临，下次再见！')

# %% [markdown]
# ## 本章小结

# %% [markdown]
# * 本章主要介绍了Python中三种重要数据结构元组、集合和字典。分别解释了它们的定义、每种数据结构的增删改查操作、相关函数以及一些简单的应用。
# * 元组的核心特点是，它是不可变序列，使用()包含若干个元素。
# * 集合是一个无序的、元素不可重复的序列，使用{}包含元素，各元素之间用逗号隔开；创建空集合时，必须使用set([]),而不是{}。因为{}是用来创建一个空字典的。
# * 字典由若干个键值对组成，也是使用{}包含了键值对。键必须是唯一的。
